# %%
import torch
import torchvision
print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
import sys
# !{sys.executable} -m pip install opencv-python matplotlib
# !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/segment-anything.git'

# !mkdir images
# !wget -P images https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/truck.jpg
# !wget -P images https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/groceries.jpg
# Out:
# PyTorch version: 2.1.0
# Torchvision version: 0.16.0
# CUDA is available: True
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/chris-lai/anaconda3/envs/bbox2seg/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.49.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/chris-lai/anaconda3/envs/bbox2seg/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/chris-lai/anaconda3/envs/bbox2seg/lib/python3.10/site-packages (from matplotlib) (10.2.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chris-lai/anaconda3/envs/bbox2seg/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/chris-lai/anaconda3/envs/bbox2seg/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# Using cached matplotlib-3.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.49.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached pyparsing-3.1.1-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, opencv-python, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.49.0 kiwisolver-1.4.5 matplotlib-3.8.3 opencv-python-4.9.0.80 pyparsing-3.1.1
# Collecting git+https://github.com/facebookresearch/segment-anything.git
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-8p4u4lcv
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-8p4u4lcv
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: segment-anything
#   Building wheel for segment-anything (setup.py) ... done
#   Created wheel for segment-anything: filename=segment_anything-1.0-py3-none-any.whl size=36586 sha256=f5653b03b863d30083de02e52c2b7fdc3b11a3252c2375c2990d8fbf16923cb3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-50sh92t9/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment-anything
# Installing collected packages: segment-anything
# Successfully installed segment-anything-1.0
# --2024-02-23 14:20:44--  https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/truck.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8000::154, 2606:50c0:8002::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8000::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 271475 (265K) [image/jpeg]
# Saving to: ‘images/truck.jpg’
#
# truck.jpg           100%[===================>] 265.11K  --.-KB/s    in 0.04s
#
# 2024-02-23 14:20:44 (6.62 MB/s) - ‘images/truck.jpg’ saved [271475/271475]
#
# --2024-02-23 14:20:45--  https://raw.githubusercontent.com/facebookresearch/segment-anything/main/notebooks/images/groceries.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8000::154, 2606:50c0:8001::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 168066 (164K) [image/jpeg]
# Saving to: ‘images/groceries.jpg’
#
# groceries.jpg       100%[===================>] 164.13K  --.-KB/s    in 0.03s
#
# 2024-02-23 14:20:45 (5.01 MB/s) - ‘images/groceries.jpg’ saved [168066/168066]

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_mask(mask, ax, random_color=False, color=None):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    elif color:
        color = np.concatenate([np.array(color), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
      
    ax.imshow(mask_image)

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))  

def show_boxes_on_image(raw_image, boxes):
    plt.figure(figsize=(10,10))
    plt.imshow(raw_image)
    for box in boxes:
      show_box(box, plt.gca())
    plt.axis('on')
    plt.show()

def show_points_on_image(raw_image, input_points, input_labels=None):
    plt.figure(figsize=(10,10))
    plt.imshow(raw_image)
    input_points = np.array(input_points)
    if input_labels is None:
      labels = np.ones_like(input_points[:, 0])
    else:
      labels = np.array(input_labels)
    show_points(input_points, labels, plt.gca())
    plt.axis('on')
    plt.show()

def show_points_and_boxes_on_image(raw_image, boxes, input_points, input_labels=None):
    plt.figure(figsize=(10,10))
    plt.imshow(raw_image)
    input_points = np.array(input_points)
    if input_labels is None:
      labels = np.ones_like(input_points[:, 0])
    else:
      labels = np.array(input_labels)
    show_points(input_points, labels, plt.gca())
    for box in boxes:
      show_box(box, plt.gca())
    plt.axis('on')
    plt.show()


def show_points_and_boxes_on_image(raw_image, boxes, input_points, input_labels=None):
    plt.figure(figsize=(10,10))
    plt.imshow(raw_image)
    input_points = np.array(input_points)
    if input_labels is None:
      labels = np.ones_like(input_points[:, 0])
    else:
      labels = np.array(input_labels)
    show_points(input_points, labels, plt.gca())
    for box in boxes:
      show_box(box, plt.gca())
    plt.axis('on')
    plt.show()


def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)

def show_mask(mask, ax, random_color=False, color=None):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    elif color:
        color = np.concatenate([np.array(color), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
      
    ax.imshow(mask_image)

def show_masks_on_image(raw_image, masks, scores):
    if len(masks.shape) == 4:
      masks = masks.squeeze()
    if scores.shape[0] == 1:
      scores = scores.squeeze()

    nb_predictions = scores.shape[-1]
    fig, axes = plt.subplots(1, nb_predictions, figsize=(15, 15))

    for i, (mask, score) in enumerate(zip(masks, scores)):
      mask = mask.cpu().detach()
      axes[i].imshow(np.array(raw_image))
      show_mask(mask, axes[i])
      axes[i].title.set_text(f"Mask {i+1}, Score: {score.item():.3f}")
      axes[i].axis("off")
    plt.show()

# %%
import os

# get all files with .jpg in all directories in ./Yolo_Dataset_2
import glob
bbox_dataset = 'datasets/Batch_6/LABELLED'
seg_dataset = 'datasets/Batch_6/CONVERTED'
image_files = glob.glob(f"./{bbox_dataset}/*.jpg", recursive=True)
label_files = glob.glob(f"./{bbox_dataset}/*.txt", recursive=True)

print("Number of images:", len(image_files))
print("Number of labels:", len(label_files))
# iterate through each image file and add it to a tuple 
image_lables = []
for imgPath in image_files:
    # get the label file path
    labelPath = imgPath.replace(".jpg", ".txt")
    # rplace images with labels
    labelPath = labelPath.replace("images", "labels")
    # add the image and label path to a tuple
    image_lables.append((imgPath, labelPath))
    
count_empty = 0
sizes = []
for lable_path in label_files:
    if os.path.getsize(lable_path) == 0:
        count_empty += 1
    sizes.append((lable_path, (os.path.getsize(lable_path))))
print("Empty Files: ", count_empty) 
print("Files Size Sorted:", sorted(sizes, key=lambda x:x[1]))

print(image_lables[0])
# Out:
# Number of images: 15100
# Number of labels: 13727
# Empty Files:  0
# ('./datasets/Batch_6/LABELLED/Image_0000034716_1667328130_428679000.jpg', './datasets/Batch_6/LABELLED/Image_0000034716_1667328130_428679000.txt')

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import os
import shutil
import numpy as np
import cv2
import torch

def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))  
def show_boxes_on_image(raw_image, boxes):
    plt.figure(figsize=(10,10))
    plt.imshow(raw_image)
    for box in boxes:
      show_box(box, plt.gca())
    plt.axis('on')
    plt.show()

def getLabels(labelPath):
    # Check if the file exists
    if not os.path.exists(labelPath):
        # Return an empty list if the file doesn't exist
        return None
    
    with open(labelPath) as f:
        # Preparing list for annotation of BB (bounding boxes)
        labels = []
        for line in f:
            labels.append(line.rstrip())

    return labels
def readLabelBB(labels, w, h):
    parsedLabels = []
    for i in range(len(labels)):
        bb_current = labels[i].split()
        objClass = bb_current[0]
        x_center, y_center = int(float(bb_current[1]) * w), int(float(bb_current[2]) * h)
        box_width, box_height = int(float(bb_current[3]) * w), int(float(bb_current[4]) * h)
        parsedLabels.append((x_center, y_center, box_width, box_height))
    return parsedLabels, objClass
def getConvertedBoxes(labels, image_width, image_height):
    converted_boxes = []
    class_ids = []
    for i in range(len(labels)):
        bb_current = labels[i].split()
        class_id = int(bb_current[0])
        x_center, y_center = float(bb_current[1]), float(bb_current[2])
        box_width, box_height = float(bb_current[3]), float(bb_current[4])
        
        # Convert to top left and bottom right coordinates
        x0 = int((x_center - box_width / 2) * image_width)
        y0 = int((y_center - box_height / 2) * image_height)
        x1 = int((x_center + box_width / 2) * image_width)
        y1 = int((y_center + box_height / 2) * image_height)
        class_ids.append(class_id)
        converted_boxes.append([x0, y0, x1, y1])
    return  class_ids, converted_boxes

def save_all_masks_on_one_image(raw_image, masks, save_dir, save_filename="all_masks_overlay"):
    raw_image_array = np.array(raw_image, dtype=np.float32)  # Convert to float for blending
    overlay_image = raw_image_array.copy()

    # Ensure save_dir exists
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Use a fixed color for visibility and debugging
    color = np.array([255.0, 0.0, 0.0, 153.0])  # Red with alpha (60% opacity when considering 255 scale)
    alpha = 0.6

    for i, mask in enumerate(masks):
        mask = mask.astype(np.float32)  # Ensure mask is float
        h, w = mask.shape
        
        # Create a colored mask
        colored_mask = np.zeros((h, w, 4), dtype=np.float32)  # Include alpha channel for the mask
        colored_mask[..., :3] = color[:3]  # Apply color
        colored_mask[..., 3] = mask * color[3]  # Apply mask's alpha channel
        
        # Alpha blending
        alpha = colored_mask[..., 3:] / 255.0  # Normalize alpha to [0, 1]
        
        overlay_image = (1 - alpha) * overlay_image + alpha * colored_mask[..., :3]
    
    # Ensure the resulting image is in the correct data type and range
    overlay_image = np.clip(overlay_image, 0, 255).astype(np.uint8)

    # Convert array to image after all masks have been applied
    overlay_pil = Image.fromarray(overlay_image)
    save_path = os.path.join(save_dir, save_filename)  # Use PNG to preserve quality
    overlay_pil.save(save_path)
    print(f"Saved: {save_path}")        

def parse_seg_label_file(seg_label_path, image_shape):
    """
    Parses a segmentation label file.

    Parameters:
    - seg_label_path: Path to the segmentation label file.
    - image_shape: Tuple of (height, width) of the corresponding image.

    Returns:
    - masks: A list of mask arrays.
    - class_ids: A list of class IDs associated with each mask.
    """
    masks = []
    class_ids = []

    with open(seg_label_path, 'r') as file:
        for line in file:
            parts = line.split()
            class_id = int(parts[0])
            # Assuming the rest of the line is normalized mask coordinates
            coords = np.array([float(x) for x in parts[1:]]).reshape(-1, 2)
            # Un-normalize coordinates
            coords[:, 0] *= image_shape[1]  # Width
            coords[:, 1] *= image_shape[0]  # Height
            # Create a blank mask
            mask = np.zeros(image_shape, dtype=np.uint8)
            # Draw the polygon on the mask
            coords = np.array([coords], dtype=np.int32)  # cv2.fillPoly expects a 3D array
            cv2.fillPoly(mask, coords, 1)
            masks.append(mask)
            class_ids.append(class_id)

    return masks, class_ids

# %%
import sys
sys.path.append("..")
from segment_anything import sam_model_registry, SamPredictor

sam_checkpoint = "sam_vit_h_4b8939.pth"
model_type = "vit_h"

device = "cuda"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
sam.to(device=device)

predictor = SamPredictor(sam)

# %%
# if you would like to plot and view the segmentation masks then set Objects list from the yaml file
Objects = []
# color rgb values for each class
color = []

SAVE_MASK_IMAGE = True

# Generate a random color for each object in the Objects list
for objects in Objects:
    color.append((np.random.randint(0,255),np.random.randint(0,255),np.random.randint(0,255)))

loopCount = 0  # Initialize loop count for tracking number of processed labels

# get image size from one image
image = cv2.imread(imgPath, cv2.IMREAD_COLOR)  # Read the image file

# Assuming image_labels is a list of tuples containing image paths and corresponding label paths
for imgPath, labelPath in image_lables:
    destination = f'{seg_dataset}/train'  # Default destination folder for training data
    if 'valid' in imgPath:  # Change destination if the image is for validation
        destination = f'{seg_dataset}/valid'
    
    if SAVE_MASK_IMAGE:
        mask_destination = f'{destination}/mask_validation'
    
    # Extract the file name without extension to use for the label file
    label_file = imgPath.split('/')[-1].split('.')[0]
    seg_label_path = os.path.join(destination, f'labels/{label_file}.txt')
    
    # Skip processing if label file already exists in the destination
    if os.path.exists(seg_label_path):
        print(f'{label_file} already exists in {destination}')
        mask_file = os.path.join(mask_destination, os.path.basename(imgPath))
        if (not os.path.exists(mask_file)) and SAVE_MASK_IMAGE:
            # Convert the PIL image for compatibility
            raw_image = Image.open(imgPath).convert("RGB")
            raw_image_array = np.array(raw_image)
            h, w = raw_image_array.shape[:2]
            
            # Parse the segmentation label file
            masks, class_ids = parse_seg_label_file(seg_label_path, (h, w))

            # Save the masks on the image
            print("Saving Validation Mask...")
            save_all_masks_on_one_image(raw_image, masks, mask_destination, save_filename=os.path.basename(imgPath))
        continue
    
    labels = getLabels(labelPath)  # Assuming getLabels is a function to parse label files
    if labels == None:
        continue # yolo format skip if there's no labels.
    
    image = cv2.imread(imgPath, cv2.IMREAD_COLOR)  # Read the image file
    predictor.set_image(image)  # Assuming predictor is a pre-defined object for predictions
    raw_image = Image.open(imgPath).convert("RGB")  # Open the image with PIL for additional operations if needed
    h, w = image.shape[:2]  # Get image dimensions
    
    # Convert bounding boxes according to the image dimensions
    class_ids, bounding_boxes = getConvertedBoxes(labels, w, h)
    
    # Convert bounding boxes to tensor and apply any necessary transformations
    input_boxes = torch.tensor(bounding_boxes, device=predictor.device)
    transformed_boxes = predictor.transform.apply_boxes_torch(input_boxes, image.shape[:2])
    
    # Predict masks based on the transformed bounding boxes
    masks, _, _ = predictor.predict_torch(
        point_coords=None,
        point_labels=None,
        boxes=transformed_boxes,
        multimask_output=False,
    )
    
    # Process each mask generated by the predictor
    for i, mask in enumerate(masks):
        binary_mask = masks[i].squeeze().cpu().numpy().astype(np.uint8)  # Convert mask to binary (0 or 1) format
        contours, hierarchy = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)  # Find contours in the binary mask
        
        try:
            largest_contour = max(contours, key=cv2.contourArea)  # Find the largest contour
            segmentation = largest_contour.flatten().tolist()  # Flatten the largest contour to a list
            mask = np.array(segmentation).reshape(-1, 2)  # Reshape for normalization
            mask_norm = mask / np.array([w, h])  # Normalize the pixel coordinates
            class_id = class_ids[i]  # Get the class ID for the current mask
            yolo = mask_norm.reshape(-1)  # Flatten the normalized mask coordinates
            
            if not os.path.exists(destination):  # Ensure the destination directory exists
                os.makedirs(destination)
            
            if SAVE_MASK_IMAGE:
                # Ensure the mask_destination directory exists
                if not os.path.exists(mask_destination):
                    os.makedirs(mask_destination)
                
                # Call the function with the correct parameters
                save_all_masks_on_one_image(raw_image, masks, mask_destination, save_filename=os.path.basename(imgPath))
            
        except Exception as e:
            continue  # Skip to the next mask if any errors occur
        
        loopCount += 1  # Increment the processed label count

        print(f'writing {label_file} to {destination}')
        print(f"file number {loopCount}")
        
        # Ensure the labels directory exists
        if not os.path.exists(os.path.join(destination, 'labels')):
            os.makedirs(os.path.join(destination, 'labels'))
        
        # Write the normalized mask coordinates to the label file
        with open(seg_label_path, "a") as f:
            for val in yolo:
                f.write(f"{class_id} {val:.6f}")
            f.write("\n")

    # Ensure the images directory exists and copy the current image to it
    if not os.path.exists(os.path.join(destination, 'images')):
        os.makedirs(os.path.join(destination, 'images'))
    shutil.copy(imgPath, f'{destination}/images')
# Out:
# Image_0000034716_1667328130_428679000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034716_1667328130_428679000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034716_1667328130_428679000.jpg
# Image_0000024444_1667327616_828736000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024444_1667327616_828736000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024444_1667327616_828736000.jpg
# Image_0000036329_1667328211_78707000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036329_1667328211_78707000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036329_1667328211_78707000.jpg
# Image_0000004430_1667326616_128470000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000004430_1667326616_128470000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000004430_1667326616_128470000.jpg
# Image_0000042506_1667328519_928480000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042506_1667328519_928480000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042506_1667328519_928480000.jpg
# Image_0000024838_1667327636_528595000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024838_1667327636_528595000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024838_1667327636_528595000.jpg
# Image_0000050306_1667328909_928670000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050306_1667328909_928670000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050306_1667328909_928670000.jpg
# Image_0000022672_1667327528_228817000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022672_1667327528_228817000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022672_1667327528_228817000.jpg
# Image_0000050933_1667328941_278483000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050933_1667328941_278483000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050933_1667328941_278483000.jpg
# Image_0000042708_1667328530_28731000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042708_1667328530_28731000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042708_1667328530_28731000.jpg
# Image_0000022067_1667327497_978481000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022067_1667327497_978481000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022067_1667327497_978481000.jpg
# Image_0000023324_1667327560_828644000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023324_1667327560_828644000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023324_1667327560_828644000.jpg
# Image_0000022647_1667327526_978766000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022647_1667327526_978766000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022647_1667327526_978766000.jpg
# Image_0000019940_1667327391_628644000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019940_1667327391_628644000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019940_1667327391_628644000.jpg
# Image_0000034779_1667328133_578656000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034779_1667328133_578656000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034779_1667328133_578656000.jpg
# Image_0000050461_1667328917_678616000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050461_1667328917_678616000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050461_1667328917_678616000.jpg
# Image_0000038111_1667328300_178656000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038111_1667328300_178656000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038111_1667328300_178656000.jpg
# Image_0000035590_1667328174_128459000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035590_1667328174_128459000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035590_1667328174_128459000.jpg
# Image_0000019934_1667327391_328664000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019934_1667327391_328664000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019934_1667327391_328664000.jpg
# Image_0000035546_1667328171_928464000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035546_1667328171_928464000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035546_1667328171_928464000.jpg
# Image_0000033945_1667328091_878452000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000033945_1667328091_878452000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000033945_1667328091_878452000.jpg
# Image_0000042585_1667328523_878626000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042585_1667328523_878626000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042585_1667328523_878626000.jpg
# Image_0000023326_1667327560_928643000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023326_1667327560_928643000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023326_1667327560_928643000.jpg
# Image_0000021928_1667327491_28517000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021928_1667327491_28517000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021928_1667327491_28517000.jpg
# Image_0000036642_1667328226_728648000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036642_1667328226_728648000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036642_1667328226_728648000.jpg
# Image_0000043031_1667328546_178649000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000043031_1667328546_178649000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000043031_1667328546_178649000.jpg
# Image_0000022712_1667327530_228741000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022712_1667327530_228741000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022712_1667327530_228741000.jpg
# Image_0000023094_1667327549_328733000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023094_1667327549_328733000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023094_1667327549_328733000.jpg
# Image_0000022535_1667327521_378634000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022535_1667327521_378634000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022535_1667327521_378634000.jpg
# Image_0000022113_1667327500_278463000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022113_1667327500_278463000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022113_1667327500_278463000.jpg
# Image_0000021500_1667327469_628637000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021500_1667327469_628637000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021500_1667327469_628637000.jpg
# Image_0000037805_1667328284_878703000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037805_1667328284_878703000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037805_1667328284_878703000.jpg
# Image_0000036005_1667328194_878538000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036005_1667328194_878538000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036005_1667328194_878538000.jpg
# Image_0000022696_1667327529_428762000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022696_1667327529_428762000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022696_1667327529_428762000.jpg
# Image_0000022386_1667327513_928468000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022386_1667327513_928468000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022386_1667327513_928468000.jpg
# Image_0000034915_1667328140_378658000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034915_1667328140_378658000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034915_1667328140_378658000.jpg
# Image_0000042704_1667328529_828698000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042704_1667328529_828698000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042704_1667328529_828698000.jpg
# Image_0000020780_1667327433_628564000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020780_1667327433_628564000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020780_1667327433_628564000.jpg
# Image_0000037923_1667328290_778698000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037923_1667328290_778698000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037923_1667328290_778698000.jpg
# Image_0000004442_1667326616_728444000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000004442_1667326616_728444000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000004442_1667326616_728444000.jpg
# Image_0000035525_1667328170_878480000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035525_1667328170_878480000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035525_1667328170_878480000.jpg
# Image_0000037654_1667328277_328547000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037654_1667328277_328547000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037654_1667328277_328547000.jpg
# Image_0000034166_1667328102_928495000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034166_1667328102_928495000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034166_1667328102_928495000.jpg
# Image_0000042789_1667328534_78763000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042789_1667328534_78763000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042789_1667328534_78763000.jpg
# Image_0000042997_1667328544_478705000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042997_1667328544_478705000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042997_1667328544_478705000.jpg
# Image_0000038332_1667328311_228671000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038332_1667328311_228671000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038332_1667328311_228671000.jpg
# Image_0000034927_1667328140_978672000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034927_1667328140_978672000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034927_1667328140_978672000.jpg
# Image_0000037418_1667328265_528482000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037418_1667328265_528482000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037418_1667328265_528482000.jpg
# Image_0000021419_1667327465_578719000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021419_1667327465_578719000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021419_1667327465_578719000.jpg
# Image_0000050174_1667328903_328709000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050174_1667328903_328709000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050174_1667328903_328709000.jpg
# Image_0000020071_1667327398_178619000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020071_1667327398_178619000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020071_1667327398_178619000.jpg
# Image_0000006139_1667326701_578486000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000006139_1667326701_578486000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000006139_1667326701_578486000.jpg
# Image_0000019025_1667327345_878487000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019025_1667327345_878487000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019025_1667327345_878487000.jpg
# Image_0000023200_1667327554_628676000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023200_1667327554_628676000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023200_1667327554_628676000.jpg
# Image_0000024285_1667327608_878714000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024285_1667327608_878714000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024285_1667327608_878714000.jpg
# Image_0000004604_1667326624_828464000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000004604_1667326624_828464000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000004604_1667326624_828464000.jpg
# Image_0000002324_1667326510_828528000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000002324_1667326510_828528000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000002324_1667326510_828528000.jpg
# Image_0000020067_1667327397_978604000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020067_1667327397_978604000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020067_1667327397_978604000.jpg
# Image_0000034813_1667328135_278621000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034813_1667328135_278621000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034813_1667328135_278621000.jpg
# Image_0000050589_1667328924_78508000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050589_1667328924_78508000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050589_1667328924_78508000.jpg
# Image_0000038102_1667328299_728689000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038102_1667328299_728689000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038102_1667328299_728689000.jpg
# Image_0000020487_1667327418_978461000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020487_1667327418_978461000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020487_1667327418_978461000.jpg
# Image_0000034853_1667328137_278633000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034853_1667328137_278633000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034853_1667328137_278633000.jpg
# Image_0000038194_1667328304_328708000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038194_1667328304_328708000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038194_1667328304_328708000.jpg
# Image_0000042372_1667328513_228456000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042372_1667328513_228456000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042372_1667328513_228456000.jpg
# Image_0000019764_1667327382_828677000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019764_1667327382_828677000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019764_1667327382_828677000.jpg
# Image_0000038078_1667328298_528676000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038078_1667328298_528676000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038078_1667328298_528676000.jpg
# Image_0000009979_1667326893_578460000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000009979_1667326893_578460000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000009979_1667326893_578460000.jpg
# Image_0000035891_1667328189_178552000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035891_1667328189_178552000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035891_1667328189_178552000.jpg
# Image_0000042693_1667328529_278685000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042693_1667328529_278685000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042693_1667328529_278685000.jpg
# Image_0000038166_1667328302_928680000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038166_1667328302_928680000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038166_1667328302_928680000.jpg
# Image_0000004695_1667326629_378457000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000004695_1667326629_378457000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000004695_1667326629_378457000.jpg
# Image_0000034394_1667328114_328569000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034394_1667328114_328569000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034394_1667328114_328569000.jpg
# Image_0000035826_1667328185_928479000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035826_1667328185_928479000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035826_1667328185_928479000.jpg
# Image_0000034283_1667328108_778500000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034283_1667328108_778500000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034283_1667328108_778500000.jpg
# Image_0000042819_1667328535_578788000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042819_1667328535_578788000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042819_1667328535_578788000.jpg
# Image_0000042523_1667328520_778522000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042523_1667328520_778522000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042523_1667328520_778522000.jpg
# Image_0000036321_1667328210_678691000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036321_1667328210_678691000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036321_1667328210_678691000.jpg
# Image_0000038203_1667328304_778659000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038203_1667328304_778659000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038203_1667328304_778659000.jpg
# Image_0000010246_1667326906_928451000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000010246_1667326906_928451000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000010246_1667326906_928451000.jpg
# Image_0000021400_1667327464_628706000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021400_1667327464_628706000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021400_1667327464_628706000.jpg
# Image_0000022840_1667327536_628688000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022840_1667327536_628688000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022840_1667327536_628688000.jpg
# Image_0000024787_1667327633_978532000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024787_1667327633_978532000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024787_1667327633_978532000.jpg
# Image_0000038753_1667328332_278488000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038753_1667328332_278488000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038753_1667328332_278488000.jpg
# Image_0000024127_1667327600_978794000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024127_1667327600_978794000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024127_1667327600_978794000.jpg
# Image_0000038422_1667328315_728675000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038422_1667328315_728675000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038422_1667328315_728675000.jpg
# Image_0000043252_1667328557_228622000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000043252_1667328557_228622000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000043252_1667328557_228622000.jpg
# Image_0000050336_1667328911_428660000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050336_1667328911_428660000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050336_1667328911_428660000.jpg
# Image_0000034958_1667328142_528653000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034958_1667328142_528653000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034958_1667328142_528653000.jpg
# Image_0000010133_1667326901_278444000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000010133_1667326901_278444000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000010133_1667326901_278444000.jpg
# Image_0000021338_1667327461_528689000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021338_1667327461_528689000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021338_1667327461_528689000.jpg
# Image_0000038396_1667328314_428650000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038396_1667328314_428650000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038396_1667328314_428650000.jpg
# Image_0000042790_1667328534_128746000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042790_1667328534_128746000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042790_1667328534_128746000.jpg
# Image_0000022172_1667327503_228485000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022172_1667327503_228485000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022172_1667327503_228485000.jpg
# Image_0000034616_1667328125_428723000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034616_1667328125_428723000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034616_1667328125_428723000.jpg
# Image_0000036971_1667328243_178556000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036971_1667328243_178556000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036971_1667328243_178556000.jpg
# Image_0000024029_1667327596_78739000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024029_1667327596_78739000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024029_1667327596_78739000.jpg
# Image_0000043163_1667328552_778943000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000043163_1667328552_778943000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000043163_1667328552_778943000.jpg
# Image_0000035710_1667328180_128462000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035710_1667328180_128462000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035710_1667328180_128462000.jpg
# Image_0000020777_1667327433_478517000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020777_1667327433_478517000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020777_1667327433_478517000.jpg
# Image_0000037880_1667328288_628707000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037880_1667328288_628707000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037880_1667328288_628707000.jpg
# Image_0000021236_1667327456_428692000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021236_1667327456_428692000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021236_1667327456_428692000.jpg
# Image_0000023073_1667327548_278709000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023073_1667327548_278709000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023073_1667327548_278709000.jpg
# Image_0000021704_1667327479_828611000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021704_1667327479_828611000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021704_1667327479_828611000.jpg
# Image_0000036930_1667328241_128594000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036930_1667328241_128594000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036930_1667328241_128594000.jpg
# Image_0000019019_1667327345_578473000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019019_1667327345_578473000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019019_1667327345_578473000.jpg
# Image_0000021358_1667327462_528666000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021358_1667327462_528666000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021358_1667327462_528666000.jpg
# Image_0000033930_1667328091_128487000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000033930_1667328091_128487000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000033930_1667328091_128487000.jpg
# Image_0000024885_1667327638_878470000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024885_1667327638_878470000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024885_1667327638_878470000.jpg
# Image_0000021724_1667327480_828575000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021724_1667327480_828575000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021724_1667327480_828575000.jpg
# Image_0000019924_1667327390_828679000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019924_1667327390_828679000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019924_1667327390_828679000.jpg
# Image_0000023636_1667327576_428473000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023636_1667327576_428473000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023636_1667327576_428473000.jpg
# Image_0000050962_1667328942_728530000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050962_1667328942_728530000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050962_1667328942_728530000.jpg
# Image_0000024107_1667327599_978740000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024107_1667327599_978740000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024107_1667327599_978740000.jpg
# Image_0000037842_1667328286_728712000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037842_1667328286_728712000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037842_1667328286_728712000.jpg
# Image_0000022637_1667327526_478740000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022637_1667327526_478740000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022637_1667327526_478740000.jpg
# Image_0000024348_1667327612_28707000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024348_1667327612_28707000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024348_1667327612_28707000.jpg
# Image_0000024721_1667327630_678575000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024721_1667327630_678575000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024721_1667327630_678575000.jpg
# Image_0000035382_1667328163_728495000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035382_1667328163_728495000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035382_1667328163_728495000.jpg
# Image_0000036534_1667328221_328630000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036534_1667328221_328630000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036534_1667328221_328630000.jpg
# Image_0000043037_1667328546_478647000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000043037_1667328546_478647000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000043037_1667328546_478647000.jpg
# Image_0000022514_1667327520_328612000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022514_1667327520_328612000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022514_1667327520_328612000.jpg
# Image_0000021199_1667327454_578716000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021199_1667327454_578716000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021199_1667327454_578716000.jpg
# Image_0000020595_1667327424_378440000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020595_1667327424_378440000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020595_1667327424_378440000.jpg
# Image_0000020975_1667327443_378697000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020975_1667327443_378697000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020975_1667327443_378697000.jpg
# Image_0000036181_1667328203_678739000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036181_1667328203_678739000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036181_1667328203_678739000.jpg
# Image_0000037674_1667328278_328528000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037674_1667328278_328528000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037674_1667328278_328528000.jpg
# Image_0000021184_1667327453_828672000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021184_1667327453_828672000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021184_1667327453_828672000.jpg
# Image_0000036946_1667328241_928560000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036946_1667328241_928560000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036946_1667328241_928560000.jpg
# Image_0000022066_1667327497_928450000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022066_1667327497_928450000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022066_1667327497_928450000.jpg
# Image_0000034114_1667328100_328470000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034114_1667328100_328470000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034114_1667328100_328470000.jpg
# Image_0000038717_1667328330_478487000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038717_1667328330_478487000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038717_1667328330_478487000.jpg
# Image_0000023786_1667327583_928449000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023786_1667327583_928449000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023786_1667327583_928449000.jpg
# Image_0000038030_1667328296_128667000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038030_1667328296_128667000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038030_1667328296_128667000.jpg
# Image_0000050822_1667328935_728466000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050822_1667328935_728466000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050822_1667328935_728466000.jpg
# Image_0000004402_1667326614_728447000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000004402_1667326614_728447000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000004402_1667326614_728447000.jpg
# Image_0000021359_1667327462_578682000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021359_1667327462_578682000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021359_1667327462_578682000.jpg
# Image_0000009984_1667326893_828863000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000009984_1667326893_828863000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000009984_1667326893_828863000.jpg
# Image_0000021435_1667327466_378667000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021435_1667327466_378667000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021435_1667327466_378667000.jpg
# Image_0000004673_1667326628_278468000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000004673_1667326628_278468000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000004673_1667326628_278468000.jpg
# Image_0000019957_1667327392_478656000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019957_1667327392_478656000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019957_1667327392_478656000.jpg
# Image_0000034838_1667328136_528635000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034838_1667328136_528635000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034838_1667328136_528635000.jpg
# Image_0000021974_1667327493_328485000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021974_1667327493_328485000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021974_1667327493_328485000.jpg
# Image_0000010152_1667326902_228479000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000010152_1667326902_228479000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000010152_1667326902_228479000.jpg
# Image_0000035414_1667328165_328495000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035414_1667328165_328495000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035414_1667328165_328495000.jpg
# Image_0000042366_1667328512_928459000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042366_1667328512_928459000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042366_1667328512_928459000.jpg
# Image_0000023856_1667327587_428486000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023856_1667327587_428486000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023856_1667327587_428486000.jpg
# Image_0000004640_1667326626_628434000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000004640_1667326626_628434000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000004640_1667326626_628434000.jpg
# Image_0000052359_1667329012_578502000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000052359_1667329012_578502000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000052359_1667329012_578502000.jpg
# Image_0000050772_1667328933_228459000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050772_1667328933_228459000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050772_1667328933_228459000.jpg
# Image_0000021603_1667327474_778632000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021603_1667327474_778632000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021603_1667327474_778632000.jpg
# Image_0000021452_1667327467_228695000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021452_1667327467_228695000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021452_1667327467_228695000.jpg
# Image_0000023494_1667327569_328508000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023494_1667327569_328508000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023494_1667327569_328508000.jpg
# Image_0000050382_1667328913_728684000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050382_1667328913_728684000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050382_1667328913_728684000.jpg
# Image_0000023063_1667327547_778713000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023063_1667327547_778713000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023063_1667327547_778713000.jpg
# Image_0000038558_1667328322_529055000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038558_1667328322_529055000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038558_1667328322_529055000.jpg
# Image_0000036084_1667328198_829041000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036084_1667328198_829041000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036084_1667328198_829041000.jpg
# Image_0000022355_1667327512_378480000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022355_1667327512_378480000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022355_1667327512_378480000.jpg
# Image_0000036751_1667328232_178650000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036751_1667328232_178650000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036751_1667328232_178650000.jpg
# Image_0000024953_1667327642_278457000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024953_1667327642_278457000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024953_1667327642_278457000.jpg
# Image_0000042768_1667328533_28796000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042768_1667328533_28796000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042768_1667328533_28796000.jpg
# Image_0000037945_1667328291_878700000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037945_1667328291_878700000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037945_1667328291_878700000.jpg
# Image_0000036225_1667328205_878684000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036225_1667328205_878684000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036225_1667328205_878684000.jpg
# Image_0000022432_1667327516_228514000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022432_1667327516_228514000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022432_1667327516_228514000.jpg
# Image_0000020483_1667327418_778462000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020483_1667327418_778462000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020483_1667327418_778462000.jpg
# Image_0000020025_1667327395_878643000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020025_1667327395_878643000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020025_1667327395_878643000.jpg
# Image_0000042740_1667328531_628772000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042740_1667328531_628772000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042740_1667328531_628772000.jpg
# Image_0000021960_1667327492_628489000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021960_1667327492_628489000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021960_1667327492_628489000.jpg
# Image_0000022278_1667327508_528463000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000022278_1667327508_528463000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000022278_1667327508_528463000.jpg
# Image_0000034293_1667328109_278482000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034293_1667328109_278482000.jpg
# Saving Validation Mask...
# ...
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050308_1667328910_28671000.jpg
# Image_0000034059_1667328097_578474000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034059_1667328097_578474000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034059_1667328097_578474000.jpg
# Image_0000034109_1667328100_78453000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034109_1667328100_78453000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034109_1667328100_78453000.jpg
# Image_0000033798_1667328084_528450000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000033798_1667328084_528450000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000033798_1667328084_528450000.jpg
# Image_0000037537_1667328271_478481000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037537_1667328271_478481000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037537_1667328271_478481000.jpg
# Image_0000021481_1667327468_678658000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021481_1667327468_678658000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021481_1667327468_678658000.jpg
# Image_0000021344_1667327461_828686000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021344_1667327461_828686000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021344_1667327461_828686000.jpg
# Image_0000035117_1667328150_478655000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035117_1667328150_478655000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035117_1667328150_478655000.jpg
# Image_0000042753_1667328532_278754000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042753_1667328532_278754000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042753_1667328532_278754000.jpg
# Image_0000050588_1667328924_28524000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050588_1667328924_28524000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050588_1667328924_28524000.jpg
# Image_0000034279_1667328108_578497000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034279_1667328108_578497000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034279_1667328108_578497000.jpg
# Image_0000038281_1667328308_678648000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038281_1667328308_678648000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038281_1667328308_678648000.jpg
# Image_0000036373_1667328213_278667000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036373_1667328213_278667000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036373_1667328213_278667000.jpg
# Image_0000043099_1667328549_578685000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000043099_1667328549_578685000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000043099_1667328549_578685000.jpg
# Image_0000034633_1667328126_278706000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034633_1667328126_278706000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034633_1667328126_278706000.jpg
# Image_0000038392_1667328314_228647000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038392_1667328314_228647000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038392_1667328314_228647000.jpg
# Image_0000034285_1667328108_878516000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034285_1667328108_878516000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034285_1667328108_878516000.jpg
# Image_0000038406_1667328314_928661000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038406_1667328314_928661000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038406_1667328314_928661000.jpg
# Image_0000034042_1667328096_728473000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034042_1667328096_728473000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034042_1667328096_728473000.jpg
# Image_0000042342_1667328511_728480000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042342_1667328511_728480000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042342_1667328511_728480000.jpg
# Image_0000019758_1667327382_528694000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019758_1667327382_528694000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019758_1667327382_528694000.jpg
# Image_0000024287_1667327608_978715000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024287_1667327608_978715000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024287_1667327608_978715000.jpg
# Image_0000035329_1667328161_78518000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035329_1667328161_78518000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035329_1667328161_78518000.jpg
# Image_0000010216_1667326905_428459000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000010216_1667326905_428459000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000010216_1667326905_428459000.jpg
# Image_0000034807_1667328134_978654000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034807_1667328134_978654000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034807_1667328134_978654000.jpg
# Image_0000006145_1667326701_878501000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000006145_1667326701_878501000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000006145_1667326701_878501000.jpg
# Image_0000034304_1667328109_828478000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034304_1667328109_828478000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034304_1667328109_828478000.jpg
# Image_0000024934_1667327641_328461000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024934_1667327641_328461000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024934_1667327641_328461000.jpg
# Image_0000033893_1667328089_278506000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000033893_1667328089_278506000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000033893_1667328089_278506000.jpg
# Image_0000023397_1667327564_478583000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023397_1667327564_478583000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023397_1667327564_478583000.jpg
# Image_0000021594_1667327474_328683000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021594_1667327474_328683000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021594_1667327474_328683000.jpg
# Image_0000043249_1667328557_78655000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000043249_1667328557_78655000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000043249_1667328557_78655000.jpg
# Image_0000038580_1667328323_628619000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038580_1667328323_628619000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038580_1667328323_628619000.jpg
# Image_0000025097_1667327649_478479000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000025097_1667327649_478479000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000025097_1667327649_478479000.jpg
# Image_0000038498_1667328319_528680000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038498_1667328319_528680000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038498_1667328319_528680000.jpg
# Image_0000023926_1667327590_928544000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023926_1667327590_928544000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023926_1667327590_928544000.jpg
# Image_0000024237_1667327606_479008000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024237_1667327606_479008000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024237_1667327606_479008000.jpg
# Image_0000023867_1667327587_978514000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023867_1667327587_978514000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023867_1667327587_978514000.jpg
# Image_0000023816_1667327585_428470000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023816_1667327585_428470000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023816_1667327585_428470000.jpg
# Image_0000019811_1667327385_178748000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000019811_1667327385_178748000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000019811_1667327385_178748000.jpg
# Image_0000024409_1667327615_78730000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000024409_1667327615_78730000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000024409_1667327615_78730000.jpg
# Image_0000036603_1667328224_778636000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036603_1667328224_778636000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036603_1667328224_778636000.jpg
# Image_0000037756_1667328282_428819000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037756_1667328282_428819000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037756_1667328282_428819000.jpg
# Image_0000036583_1667328223_778639000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036583_1667328223_778639000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036583_1667328223_778639000.jpg
# Image_0000037768_1667328283_29027000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037768_1667328283_29027000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037768_1667328283_29027000.jpg
# Image_0000023103_1667327549_778730000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023103_1667327549_778730000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023103_1667327549_778730000.jpg
# Image_0000034111_1667328100_178468000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034111_1667328100_178468000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034111_1667328100_178468000.jpg
# Image_0000023832_1667327586_228463000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000023832_1667327586_228463000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000023832_1667327586_228463000.jpg
# Image_0000038539_1667328321_578642000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000038539_1667328321_578642000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000038539_1667328321_578642000.jpg
# Image_0000037677_1667328278_478513000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000037677_1667328278_478513000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000037677_1667328278_478513000.jpg
# Image_0000042805_1667328534_878792000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000042805_1667328534_878792000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000042805_1667328534_878792000.jpg
# Image_0000035188_1667328154_28645000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000035188_1667328154_28645000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000035188_1667328154_28645000.jpg
# Image_0000020553_1667327422_278448000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000020553_1667327422_278448000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000020553_1667327422_278448000.jpg
# Image_0000036934_1667328241_328593000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000036934_1667328241_328593000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000036934_1667328241_328593000.jpg
# Image_0000050394_1667328914_328638000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000050394_1667328914_328638000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000050394_1667328914_328638000.jpg
# Image_0000021441_1667327466_678665000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000021441_1667327466_678665000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000021441_1667327466_678665000.jpg
# Image_0000034768_1667328133_29585000 already exists in datasets/Batch_6/CONVERTED/train
# ./datasets/Batch_6/LABELLED/Image_0000034768_1667328133_29585000.jpg
# Saving Validation Mask...
# Saved: datasets/Batch_6/CONVERTED/train/mask_validation/Image_0000034768_1667328133_29585000.jpg

# %%
# zip seg_dataset folder
shutil.make_archive(seg_dataset, 'zip', seg_dataset)
# Out:
# '/notebooks/Yolo_Seg.zip'

# %%
# Convert Everything from the Filepath into a Video

# %%
# from PIL import Image
# import os
# import shutil
# # if you would like to plot and view the segmentation masks then set Objects list from the yaml file
# Objects = []
# # color rgb values for each class
# color = []

# for objects in Objects:
#     # create a random color and add it to the color list
#     color.append((np.random.randint(0,255),np.random.randint(0,255),np.random.randint(0,255)))
# loopCount = 0
# for imgPath, labelPath in image_lables:
#     destination = f'{seg_dataset}/train'
#     if 'valid' in imgPath:
#         destination = f'{seg_dataset}/valid'
#     # if label file is in destination folder then skip
#     label_file = imgPath.split('/')[-1].split('.')[0]
#     seg_label_path = os.path.join(destination, f'labels/{label_file}.txt')
#     if os.path.exists(seg_label_path):
#         label_file = imgPath.split('/')[-1].split('.')[0]
#         print(f'{label_file} already exists in {destination}')
#         continue
#     labels = getLabels(labelPath)
#     image = cv2.imread(imgPath, cv2.IMREAD_COLOR)
#     predictor.set_image(image)
#     raw_image = Image.open(imgPath).convert("RGB")
#     h, w = image.shape[:2]
#     class_ids, bounding_boxes = getConvertedBoxes(labels, w, h)
#     # show_boxes_on_image(raw_image, bounding_boxes) 
#     input_boxes = torch.tensor(bounding_boxes, device=predictor.device)
#     transformed_boxes = predictor.transform.apply_boxes_torch(input_boxes, image.shape[:2])
#     masks, _, _ = predictor.predict_torch(
#         point_coords=None,
#         point_labels=None,
#         boxes=transformed_boxes,
#         multimask_output=False,
#     )
#     for i,mask in enumerate(masks):
#         binary_mask = masks[i].squeeze().cpu().numpy().astype(np.uint8)
#         contours, hierarchy = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#         try:
#             largest_contour = max(contours, key=cv2.contourArea)
#             segmentation = largest_contour.flatten().tolist()
#             mask = segmentation

#             # convert mask to numpy array of shape (N,2)
#             mask = np.array(mask).reshape(-1, 2)

#             # normalize the pixel coordinates
#             mask_norm = mask / np.array([w, h])
#             class_id = class_ids[i]
#             yolo = mask_norm.reshape(-1)
#             # show_mask(mask.cpu().numpy(), plt.gca(), random_color=False, color=color[class_id])
#             # check if train or valid in imagPath
        
#             # if folder does not exist, create it
#             if not os.path.exists(destination):
#                 os.makedirs(destination)
#         except Exception as e:
#             continue
#         # label file name
#         loopCount += 1

#         print(f'writing {label_file} to {destination}')
#         print(f"file number {loopCount}")
#         # create labels folder if it does not exist
#         if not os.path.exists(os.path.join(destination, 'labels')):
#             os.makedirs(os.path.join(destination, 'labels'))
#         with open(seg_label_path, "a") as f:
#             for val in yolo:
#                 f.write("{} {:.6f}".format(class_id,val))
#             f.write("\n")

#     # create images folder if it does not exist
#     if not os.path.exists(os.path.join(destination, 'images')):
#         os.makedirs(os.path.join(destination, 'images'))
#     # copy image to destination/images
#     shutil.copy(imgPath, f'{destination}/images')
#     # for box in input_boxes:
#     #     show_box(box.cpu().numpy(), plt.gca())
#     # plt.axis('off')
#     # plt.show()
#     # if loopCount == 10:
#     #     break
